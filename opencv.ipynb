# %%
import cv2 as cv

# %%
img = cv.imread('cat_large.jpg')

# %%
cv.imshow('Cat', img)
cv.waitKey(0)
# Out:
# ...
# QObject::moveToThread: Current thread (0x55562c1e8f50) is not the object's thread (0x55562d2fa320).
# Cannot move to target thread (0x55562c1e8f50)
#
# QObject::moveToThread: Current thread (0x55562c1e8f50) is not the object's thread (0x55562d2fa320).
# Cannot move to target thread (0x55562c1e8f50)
#
# QObject::moveToThread: Current thread (0x55562c1e8f50) is not the object's thread (0x55562d2fa320).
# Cannot move to target thread (0x55562c1e8f50)
#
# QObject::moveToThread: Current thread (0x55562c1e8f50) is not the object's thread (0x55562d2fa320).
# Cannot move to target thread (0x55562c1e8f50)
#
# QObject::moveToThread: Current thread (0x55562c1e8f50) is not the object's thread (0x55562d2fa320).
# Cannot move to target thread (0x55562c1e8f50)
#
# QObject::moveToThread: Current thread (0x55562c1e8f50) is not the object's thread (0x55562d2fa320).
# Cannot move to target thread (0x55562c1e8f50)
#
# ...
